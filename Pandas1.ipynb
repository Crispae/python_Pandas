# %%
#importing pandas
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.__dir__()
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
print(df.join.__doc__)
# Out:
#         Join columns of another DataFrame.
#
#         Join columns with `other` DataFrame either on index or on a key
#         column. Efficiently join multiple DataFrame objects by index at once by
#         passing a list.
#
#         Parameters
#         ----------
#         other : DataFrame, Series, or list of DataFrame
#             Index should be similar to one of the columns in this one. If a
#             Series is passed, its name attribute must be set, and that will be
#             used as the column name in the resulting joined DataFrame.
#         on : str, list of str, or array-like, optional
#             Column or index level name(s) in the caller to join on the index
#             in `other`, otherwise joins index-on-index. If multiple
#             values given, the `other` DataFrame must have a MultiIndex. Can
#             pass an array as the join key if it is not already contained in
#             the calling DataFrame. Like an Excel VLOOKUP operation.
# ...

# %%
"""

Parameters
----------
other : scalar, sequence, Series, or DataFrame
    Any single or multiple element data structure, or list-like object.
axis : {0 or 'index', 1 or 'columns'}, default 'columns'
    Whether to compare by the index (0 or 'index') or columns
    (1 or 'columns').
level : int or label
    Broadcast across a level, matching Index values on the passed
    MultiIndex level.


COMPARISION OPERATOR

DataFrame.eq : Compare DataFrames for equality elementwise.
DataFrame.ne : Compare DataFrames for inequality elementwise.
DataFrame.le : Compare DataFrames for less than inequality
    or equality elementwise.
DataFrame.lt : Compare DataFrames for strictly less than
    inequality elementwise.
DataFrame.ge : Compare DataFrames for greater than inequality
    or equality elementwise.
DataFrame.gt : Compare DataFrames for strictly greater than
    inequality elementwise.

Notes
-----
Mismatched indices will be unioned together.
`NaN` values are considered different (i.e. `NaN` != `NaN`).









"""

# %%
"""
ARTHIMETIC OPERATION DONE ON DATA FRAME

Parameters
----------
other : scalar, sequence, Series, or DataFrame
    Any single or multiple element data structure, or list-like object.
axis : {0 or 'index', 1 or 'columns'}
    Whether to compare by the index (0 or 'index') or columns
    (1 or 'columns'). For Series input, axis to match Series index on.
level : int or label
    Broadcast across a level, matching Index values on the
    passed MultiIndex level.
fill_value : float or None, default None
    Fill existing missing (NaN) values, and any new element needed for
    successful DataFrame alignment, with this value before computation.
    If data in both corresponding DataFrame locations is missing
    the result will be missing.

Returns
-------
DataFrame
    Result of the arithmetic operation.


DataFrame.add : Add DataFrames.
DataFrame.sub : Subtract DataFrames.
DataFrame.mul : Multiply DataFrames.
DataFrame.div : Divide DataFrames (float division).
DataFrame.truediv : Divide DataFrames (float division).
DataFrame.floordiv : Divide DataFrames (integer division).
DataFrame.mod : Calculate modulo (remainder after division).
DataFrame.pow : Calculate exponential power.
"""
# Out:
# "\nARTHIMETIC OPERATION DONE ON DATA FRAME\n\nParameters\n----------\nother : scalar, sequence, Series, or DataFrame\n    Any single or multiple element data structure, or list-like object.\naxis : {0 or 'index', 1 or 'columns'}\n    Whether to compare by the index (0 or 'index') or columns\n    (1 or 'columns'). For Series input, axis to match Series index on.\nlevel : int or label\n    Broadcast across a level, matching Index values on the\n    passed MultiIndex level.\nfill_value : float or None, default None\n    Fill existing missing (NaN) values, and any new element needed for\n    successful DataFrame alignment, with this value before computation.\n    If data in both corresponding DataFrame locations is missing\n    the result will be missing.\n\nReturns\n-------\nDataFrame\n    Result of the arithmetic operation.\n\n\nDataFrame.add : Add DataFrames.\nDataFrame.sub : Subtract DataFrames.\nDataFrame.mul : Multiply DataFrames.\nDataFrame.div : Divide DataFrames (float division)
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'survived'}>,
#         <AxesSubplot:title={'center':'pclass'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sibsp'}>],
#        [<AxesSubplot:title={'center':'parch'}>,
#         <AxesSubplot:title={'center':'fare'}>]], dtype=object)

# %%
df.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 100         0       3    male  22.0      1      0   7.2500        S  NaN
# 101         1       1  female  38.0      1      0  71.2833        C    C
# 102         1       3  female  26.0      0      0   7.9250        S  NaN
# 103         1       1  female  35.0      1      0  53.1000        S    C
# 104         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
col = [x for x in range(891)]

# %%
df

# %%
df.insert(loc=4,column="testing",value=[x for x in range(891)])
## It will insert a particular column in the datframe at location given by loc argument,column name
## will be the label of colum
## If that column name already exists it will not insert that column and it will raise
## value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-25b817de525d> in <module>
# ----> 1 df.insert(loc=4,column="testing",value=[x for x in range(891)])
#       2 ## It will insert a particular column in the datframe at location given by loc argument,column name
#       3 ## will be the label of colum
#
# c:\users\saurav\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# -> 3628         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3629
#    3630     def assign(self, **kwargs) -> "DataFrame":
#
# ...

# %%
df
# Out:
#      survived  pclass     sex    age  testing  sibsp  parch      fare  \
# 100         0       3    male  22.00        0      1      0    7.2500
# 101         1       1  female  38.00        1      1      0   71.2833
# 102         1       3  female  26.00        2      0      0    7.9250
# 103         1       1  female  35.00        3      1      0   53.1000
# 104         0       3    male  35.00        4      0      0    8.0500
# 105         0       3    male    NaN        5      0      0    8.4583
# 106         0       1    male  54.00        6      0      0   51.8625
# 107         0       3    male   2.00        7      3      1   21.0750
# 108         1       3  female  27.00        8      0      2   11.1333
# 109         1       2  female  14.00        9      1      0   30.0708
# 110         1       3  female   4.00       10      1      1   16.7000
# 111         1       1  female  58.00       11      0      0   26.5500
# ...

# %%
for i in df.itertuples():
    print(i)
## this will return over all the dataframe and represent all the rows as a named tuple
# Out:
# Pandas(Index=100, survived=0, pclass=3, sex='male', age=22.0, testing=0, sibsp=1, parch=0, fare=7.25, embarked='S', deck=nan)
# Pandas(Index=101, survived=1, pclass=1, sex='female', age=38.0, testing=1, sibsp=1, parch=0, fare=71.2833, embarked='C', deck='C')
# Pandas(Index=102, survived=1, pclass=3, sex='female', age=26.0, testing=2, sibsp=0, parch=0, fare=7.925, embarked='S', deck=nan)
# Pandas(Index=103, survived=1, pclass=1, sex='female', age=35.0, testing=3, sibsp=1, parch=0, fare=53.1, embarked='S', deck='C')
# Pandas(Index=104, survived=0, pclass=3, sex='male', age=35.0, testing=4, sibsp=0, parch=0, fare=8.05, embarked='S', deck=nan)
# Pandas(Index=105, survived=0, pclass=3, sex='male', age=nan, testing=5, sibsp=0, parch=0, fare=8.4583, embarked='Q', deck=nan)
# Pandas(Index=106, survived=0, pclass=1, sex='male', age=54.0, testing=6, sibsp=0, parch=0, fare=51.8625, embarked='S', deck='E')
# ...

# %%
for index,i in df.iterrows():
    print(f"Index Number: {index}")
    print(f"{i}",end="\n")
## Iterrows is a generator it will iterate over all the row and give all the feature data row wise
# Out:
# Index Number: 100
# survived       0
# pclass         3
# sex         male
# age           22
# testing        0
# sibsp          1
# parch          0
# fare        7.25
# embarked       S
# deck         NaN
# Name: 100, dtype: object
# Index Number: 101
# survived          1
# pclass            1
# sex          female
# age              38
# testing           1
# sibsp             1
# parch             0
# fare        71.2833
# embarked          C
# deck              C
# Name: 101, dtype: object
# Index Number: 102
# survived         1
# pclass           3
# sex         female
# age             26
# testing          2
# sibsp            0
# parch            0
# fare         7.925
# embarked         S
# deck           NaN
# Name: 102, dtype: object
# Index Number: 103
# survived         1
# pclass           1
# sex         female
# age             35
# testing          3
# sibsp            1
# parch            0
# fare          53.1
# embarked         S
# deck             C
# ...

# %%
for content, i in df.items():
    print(f"Content: {content}")
    print(f"{i}",end="\n")
    
## here it will iterate over each column and it will represent its data
# Out:
# Content: survived
# 100    0
# 101    1
# 102    1
# 103    1
# 104    0
# 105    0
# 106    0
# 107    0
# 108    1
# 109    1
# 110    1
# 111    1
# 112    0
# 113    0
# 114    0
# 115    1
# 116    0
# 117    1
# 118    0
# 119    1
# 120    0
# 121    1
# 122    1
# 123    1
# 124    0
# 125    1
# 126    0
# 127    0
# 128    1
# 129    0
# 130    0
# 131    1
# 132    1
# 133    0
# 134    0
# 135    0
# 136    1
# 137    0
# 138    0
# 139    1
# 140    0
# 141    0
# 142    0
# 143    1
# 144    1
# 145    0
# 146    0
# 147    1
# 148    0
# 149    0
# 150    0
# 151    0
# 152    1
# 153    1
# 154    0
# 155    1
# 156    1
# 157    0
# 158    1
# 159    0
# 160    0
# 161    1
# 162    0
# 163    0
# 164    0
# 165    1
# 166    1
# 167    0
# 168    1
# 169    0
# 170    0
# 171    0
# 172    0
# 173    0
# 174    1
# 175    0
# 176    0
# 177    0
# 178    1
# 179    1
# 180    0
# 181    1
# 182    1
# 183    0
# 184    1
# 185    1
# 186    0
# 187    0
# 188    1
# ...

# %%
df.isna()
## isnull is alias of isna
## This will return which element has NA value
# Out:
#      survived  pclass    sex    age  testing  sibsp  parch   fare  embarked  \
# 100     False   False  False  False    False  False  False  False     False
# 101     False   False  False  False    False  False  False  False     False
# 102     False   False  False  False    False  False  False  False     False
# 103     False   False  False  False    False  False  False  False     False
# 104     False   False  False  False    False  False  False  False     False
# ..        ...     ...    ...    ...      ...    ...    ...    ...       ...
# 986     False   False  False  False    False  False  False  False     False
# 987     False   False  False  False    False  False  False  False     False
# 988     False   False  False   True    False  False  False  False     False
# 989     False   False  False  False    False  False  False  False     False
# 990     False   False  False  False    False  False  False  False     False
#
#       deck
# 100   True
# 101  False
# 102   True
# ...

# %%
pd.options.display.max_rows = None
new1 = df["deck"].isna()
df[new1]
## here we have filter the NaN value in deck column and select create a dataframe which contain only 
## NAN value
# Out:
#      survived  pclass     sex    age  testing  sibsp  parch      fare  \
# 100         0       3    male  22.00        0      1      0    7.2500
# 102         1       3  female  26.00        2      0      0    7.9250
# 104         0       3    male  35.00        4      0      0    8.0500
# 105         0       3    male    NaN        5      0      0    8.4583
# 107         0       3    male   2.00        7      3      1   21.0750
# 108         1       3  female  27.00        8      0      2   11.1333
# 109         1       2  female  14.00        9      1      0   30.0708
# 112         0       3    male  20.00       12      0      0    8.0500
# 113         0       3    male  39.00       13      1      5   31.2750
# 114         0       3  female  14.00       14      0      0    7.8542
# 115         1       2  female  55.00       15      0      0   16.0000
# 116         0       3    male   2.00       16      4      1   29.1250
# ...

# %%
new = df["sex"].isin(["male"])
df[new]
## Best use of isin in this link to apply filter and select only that data
### https://www.geeksforgeeks.org/python-pandas-dataframe-isin/
# Out:
#      survived  pclass   sex   age  testing  sibsp  parch     fare embarked  \
# 100         0       3  male  22.0        0      1      0   7.2500        S
# 104         0       3  male  35.0        4      0      0   8.0500        S
# 105         0       3  male   NaN        5      0      0   8.4583        Q
# 106         0       1  male  54.0        6      0      0  51.8625        S
# 107         0       3  male   2.0        7      3      1  21.0750        S
# ..        ...     ...   ...   ...      ...    ...    ...      ...      ...
# 983         0       2  male  28.0      883      0      0  10.5000        S
# 984         0       3  male  25.0      884      0      0   7.0500        S
# 986         0       2  male  27.0      886      0      0  13.0000        S
# 989         1       1  male  26.0      889      0      0  30.0000        C
# 990         0       3  male  32.0      890      0      0   7.7500        Q
#
#     deck
# 100  NaN
# 104  NaN
# 105  NaN
# 106    E
# 107  NaN
# ...

# %%
df.isin({"embarked":["A","B","C","D","S"]})
# Out:
#      survived  pclass    sex    age  testing  sibsp  parch   fare  embarked  \
# 100     False   False  False  False    False  False  False  False      True
# 101     False   False  False  False    False  False  False  False      True
# 102     False   False  False  False    False  False  False  False      True
# 103     False   False  False  False    False  False  False  False      True
# 104     False   False  False  False    False  False  False  False      True
# ..        ...     ...    ...    ...      ...    ...    ...    ...       ...
# 986     False   False  False  False    False  False  False  False      True
# 987     False   False  False  False    False  False  False  False      True
# 988     False   False  False  False    False  False  False  False      True
# 989     False   False  False  False    False  False  False  False      True
# 990     False   False  False  False    False  False  False  False     False
#
#       deck
# 100  False
# 101  False
# 102  False
# ...

# %%
df.isin([3,5,"male"])
## This will check the values in the list in the dataframe if the value exist there will be true
## if there will be not present it will be false the it will search for entire dataFrame
# Out:
#      survived  pclass    sex    age  testing  sibsp  parch   fare  embarked  \
# 100     False    True   True  False    False  False  False  False     False
# 101     False   False  False  False    False  False  False  False     False
# 102     False    True  False  False    False  False  False  False     False
# 103     False   False  False  False     True  False  False  False     False
# 104     False    True   True  False    False  False  False  False     False
# ..        ...     ...    ...    ...      ...    ...    ...    ...       ...
# 986     False   False   True  False    False  False  False  False     False
# 987     False   False  False  False    False  False  False  False     False
# 988     False    True  False  False    False  False  False  False     False
# 989     False   False   True  False    False  False  False  False     False
# 990     False    True   True  False    False  False  False  False     False
#
#       deck
# 100  False
# 101  False
# 102  False
# ...

# %%
pd.options.__dir__()
# Out:
# ['display', 'compute', 'mode', 'io', 'plotting']

# %%
pd.options.display.__dir__()
# Out:
# ['date_dayfirst',
#  'date_yearfirst',
#  'encoding',
#  'precision',
#  'float_format',
#  'column_space',
#  'max_info_rows',
#  'max_rows',
#  'min_rows',
#  'max_categories',
#  'max_colwidth',
#  'max_columns',
#  'large_repr',
#  'max_info_columns',
#  'colheader_justify',
#  'notebook_repr_html',
#  'pprint_nest_depth',
#  'multi_sparse',
#  'expand_frame_repr',
#  'show_dimensions',
#  'chop_threshold',
#  'max_seq_items',
#  'width',
#  'memory_usage',
#  'unicode',
#  'latex',
#  'html']

# %%
pd.options.compute.__dir__()
# Out:
# ['use_bottleneck', 'use_numexpr', 'use_numba']

# %%
pd.options.mode.__dir__()
# Out:
# ['sim_interactive', 'use_inf_as_na', 'use_inf_as_null', 'chained_assignment']

# %%
pd.options.io.__dir__()
# Out:
# ['excel', 'parquet', 'hdf']

# %%
pd.options.plotting.__dir__()
# Out:
# ['backend', 'matplotlib']

# %%
pd.options.display.max_rows = 891

# %%
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 100         0       3    male  22.00      1      0    7.2500        S  NaN
# 101         1       1  female  38.00      1      0   71.2833        C    C
# 102         1       3  female  26.00      0      0    7.9250        S  NaN
# 103         1       1  female  35.00      1      0   53.1000        S    C
# 104         0       3    male  35.00      0      0    8.0500        S  NaN
# 105         0       3    male    NaN      0      0    8.4583        Q  NaN
# 106         0       1    male  54.00      0      0   51.8625        S    E
# 107         0       3    male   2.00      3      1   21.0750        S  NaN
# 108         1       3  female  27.00      0      2   11.1333        S  NaN
# 109         1       2  female  14.00      1      0   30.0708        C  NaN
# 110         1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 100 to 990
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
#df.index = pd.RangeIndex(start=100,stop=991,)
df
## If we have to set range of index we can use RangeIndex constructor which will create a index according
## to start stop and step value which we replace with our exixting datafram index
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 100         0       3    male  22.0      1      0   7.2500        S  NaN
# 101         1       1  female  38.0      1      0  71.2833        C    C
# 102         1       3  female  26.0      0      0   7.9250        S  NaN
# 103         1       1  female  35.0      1      0  53.1000        S    C
# 104         0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 986         0       2    male  27.0      0      0  13.0000        S  NaN
# 987         1       1  female  19.0      0      0  30.0000        S    B
# 988         0       3  female   NaN      1      2  23.4500        S  NaN
# 989         1       1    male  26.0      0      0  30.0000        C    C
# 990         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.iloc[2:4,2:6].infer_objects().dtypes
## only numeric value will take
# Out:
# sex       object
# age      float64
# sibsp      int64
# parch      int64
# dtype: object

# %%
df.loc[[0,2],["sex","age"]]
## loc will take label name as an argument
# Out:
#       sex   age
# 0    male  22.0
# 2  female  26.0

# %%
df.iloc[2]
## series type
## in iloc only numeric indexer is required
## it will take index postion of rows and column
# Out:
# survived         1
# pclass           3
# sex         female
# age             26
# sibsp            0
# parch            0
# fare         7.925
# embarked         S
# deck           NaN
# Name: 2, dtype: object

# %%
df.iloc[[0],[4]]
## dataframe
# Out:
#      testing
# 100        0

# %%
type(df.iloc)
## Where we get Indexer type of object it means it there will we indexing take place 
## like list or dictionary
# Out:
# pandas.core.indexing._iLocIndexer

# %%
type(df.iat)
# Out:
# pandas.core.indexing._iAtIndexer

# %%
type(df.at)
# Out:
# pandas.core.indexing._AtIndexer

# %%
type(df.loc)
# Out:
# pandas.core.indexing._LocIndexer

# %%
df.iloc[3:4,:].at[3,"sex"]
## using iloc and at at same time
# Out:
# 'female'

# %%
## column can be indexed directly from dataframe like a dictionay key pair value.

# %%
pd.options.display.max_rows = 20

# %%
df["sex"]
# Out:
# 100      male
# 101    female
# 102    female
# 103    female
# 104      male
#         ...
# 986      male
# 987    female
# 988    female
# 989      male
# 990      male
# Name: sex, Length: 891, dtype: object

# %%
df[["sex","fare"]]
# Out:
#         sex     fare
# 0      male   7.2500
# 1    female  71.2833
# 2    female   7.9250
# 3    female  53.1000
# 4      male   8.0500
# ..      ...      ...
# 886    male  13.0000
# 887  female  30.0000
# 888  female  23.4500
# 889    male  30.0000
# 890    male   7.7500
#
# [891 rows x 2 columns]

# %%
df.get("pclass")
## It will be like dict get it will return a particular column by using the labael
## name of that column as key
## if cloumn will not exist it will return defalt value
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
df.iat[3,2]
## index a particlar value
## it takes index postion to fetch a particlar row and colmnn vale
# Out:
# 'female'

# %%
df.at[3,"fare"]
## It takes label name to get a particlar colmn and row valuue
# Out:
# 53.1

# %%
df.dtypes
## it will return the data types of the features
## int64 --> integer
## object --> it is basically a string or mixture of string and number
## float64 --> decimal dataype
## NaN --> not a number
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
df.count()
## it will count the numeber of elements in each feature column
# Out:
# survived    891
# pclass      891
# sex         891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
df.columns
## This will return all the columns in the dataframe
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
## we can iterate throigh all the coulmn name
# Out:
# survived
# pclass
# sex
# age
# testing
# sibsp
# parch
# fare
# embarked
# deck

# %%
df.axes
## axes is a type of  attribute which will return a list object which conatin the index of both rangeindex
# which is index in terms of rows and index in terms of column
# Out:
# [RangeIndex(start=100, stop=991, step=1),
#  Index(['survived', 'pclass', 'sex', 'age', 'testing', 'sibsp', 'parch', 'fare',
#         'embarked', 'deck'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object
